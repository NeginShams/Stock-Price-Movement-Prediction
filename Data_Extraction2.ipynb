# %%
import os
print(os.getcwd())
# Out:
# C:\Users\Partiran\Desktop

# %%
import requests
import time
import json
from datetime import datetime

# Configuration
API_URL = "https://rahavard365.com/api/v2/social/posts"
OUTPUT_FILE = f"filtered_posts_{datetime.now().strftime('%Y%m%d_%H%M%S')}.json"
TARGET_ENTITY_ID = "7836"  # specific entity ID
MAX_REQUESTS = 700
DELAY = 1.5  # seconds

# Headers from browser inspection
headers = {
    "authority": "rahavard365.com",
    "accept": "application/json, text/plain, */*",
    "accept-language": "en-US,en;q=0.9",
    "application-name": "rahavard",
    "content-type": "application/json",
    "referer": "https://rahavard365.com/social",
    "user-agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/123.0.0.0 Safari/537.36"
}

# Initialize storage
filtered_posts = []
last_id = None
request_count = 0

print(f"Starting to collect posts for entity ID: {TARGET_ENTITY_ID}")

while request_count < MAX_REQUESTS:
    # Prepare parameters
    params = {
        "exclude_replies": "true",
        "has_chart_analysis": "false",
        "_count": 16,
        "entity_id": TARGET_ENTITY_ID,
        "entity_type": "exchange.asset",
        "_t": int(time.time() * 1000),
    }
    
    if last_id:
        params["before_id"] = last_id
    
    try:
        print(f"\nRequest #{request_count + 1}")
        # print(f"Params: {params}")
        
        response = requests.get(
            API_URL,
            params=params,
            headers=headers,
            timeout=10
        )
        request_count += 1
        
        print(f"Status: {response.status_code}")
        
        if response.status_code == 200:
            data = response.json()
            
            if isinstance(data, dict) and data.get("data"):
                batch = data["data"]
                
                if not batch:
                    print("No more posts available")
                    break
                
                # Verify entity_id in each post
                valid_posts = [
                    p for p in batch 
                    if str(p.get("entity_id")) == TARGET_ENTITY_ID
                ]
                
                if len(valid_posts) != len(batch):
                    print(f"Filtered {len(batch) - len(valid_posts)} posts with wrong entity_id")
                
                if valid_posts:
                    filtered_posts.extend(valid_posts)
                    last_id = valid_posts[-1]["id"]
                    # print(f"Added {len(valid_posts)} valid posts (Total: {len(filtered_posts)})")
                else:
                    print("No valid posts in this batch")
                    break
            else:
                print("Unexpected response format")
                break
        else:
            print(f"HTTP Error {response.status_code}")
            break
            
        time.sleep(DELAY)
        
    except Exception as e:
        print(f"Error: {str(e)}")
        break

# Save results
print(f"\nFinished. Collected {len(filtered_posts)} posts for entity {TARGET_ENTITY_ID}")
with open(OUTPUT_FILE, "w", encoding="utf-8") as f:
    json.dump(filtered_posts, f, ensure_ascii=False, indent=2)

print(f"Results saved to {OUTPUT_FILE}")

# Verification
if filtered_posts:
    print("\nVerification:")
    print(f"First post entity_id: {filtered_posts[0].get('entity_id')}")
    print(f"Last post entity_id: {filtered_posts[-1].get('entity_id')}")
    print(f"Unique entity_ids found: {len(set(p.get('entity_id') for p in filtered_posts))}")
# Out:
# Starting to collect posts for entity ID: 7836
#
# Request #1
# Status: 200
#
# Request #2
# Status: 200
#
# Request #3
# Status: 200
#
# Request #4
# Status: 200
#
# Request #5
# Status: 200
#
# Request #6
# Status: 200
#
# Request #7
# Status: 200
#
# Request #8
# Status: 200
#
# Request #9
# Status: 200
#
# Request #10
# Status: 200
#
# Request #11
# Status: 200
#
# Request #12
# Status: 200
#
# Request #13
# Status: 200
#
# Request #14
# Status: 200
#
# Request #15
# Status: 200
#
# Request #16
# Status: 200
#
# Request #17
# Status: 200
#
# Request #18
# Status: 200
#
# Request #19
# Status: 200
#
# Request #20
# Status: 200
#
# Request #21
# Status: 200
#
# Request #22
# Status: 200
#
# Request #23
# Status: 200
#
# Request #24
# Status: 200
#
# Request #25
# Status: 200
#
# Request #26
# Status: 200
#
# Request #27
# Status: 200
#
# Request #28
# Status: 200
#
# Request #29
# Status: 200
#
# Request #30
# Status: 200
#
# Request #31
# Status: 200
#
# Request #32
# Status: 200
#
# Request #33
# Status: 200
#
# Request #34
# Status: 200
#
# Request #35
# Status: 200
#
# Request #36
# Status: 200
#
# Request #37
# Status: 200
#
# Request #38
# Status: 200
#
# Request #39
# Status: 200
#
# Request #40
# Status: 200
#
# Request #41
# Status: 200
#
# Request #42
# Status: 200
#
# Request #43
# Status: 200
#
# Request #44
# Status: 200
#
# Request #45
# Status: 200
#
# Request #46
# Status: 200
#
# Request #47
# Status: 200
#
# Request #48
# Status: 200
#
# Request #49
# Status: 200
#
# Request #50
# Status: 200
#
# Request #51
# Status: 200
#
# Request #52
# Status: 200
#
# Request #53
# Status: 200
#
# Request #54
# Status: 200
#
# Request #55
# Status: 200
#
# Request #56
# Status: 200
#
# Request #57
# Status: 200
#
# Request #58
# Status: 200
#
# Request #59
# Status: 200
#
# Request #60
# Status: 200
#
# Request #61
# Status: 200
#
# Request #62
# Status: 200
#
# Request #63
# Status: 200
#
# Request #64
# Status: 200
#
# Request #65
# Status: 200
#
# Request #66
# Status: 200
#
# Request #67
# Status: 200
#
# Request #68
# Status: 200
#
# Request #69
# Status: 200
#
# Request #70
# Status: 200
#
# Request #71
# Status: 200
#
# Request #72
# Status: 200
#
# Request #73
# Status: 200
#
# Request #74
# Status: 200
#
# Request #75
# Status: 200
#
# Request #76
# Status: 200
#
# Request #77
# Status: 200
#
# Request #78
# Status: 200
#
# Request #79
# Status: 200
#
# Request #80
# Status: 200
#
# Request #81
# Status: 200
#
# Request #82
# Status: 200
#
# Request #83
# Status: 200
#
# Request #84
# Status: 200
#
# Request #85
# Status: 200
#
# Request #86
# Status: 200
#
# Request #87
# Status: 200
#
# Request #88
# Status: 200
#
# Request #89
# Status: 200
#
# Request #90
# Status: 200
#
# Request #91
# Status: 200
#
# Request #92
# Status: 200
#
# Request #93
# Status: 200
#
# Request #94
# Status: 200
#
# Request #95
# Status: 200
#
# Request #96
# Status: 200
#
# Request #97
# Status: 200
#
# Request #98
# Status: 200
#
# Request #99
# Status: 200
#
# Request #100
# Status: 200
#
# Request #101
# Status: 200
#
# Request #102
# Status: 200
#
# Request #103
# Status: 200
#
# Request #104
# Status: 200
#
# Request #105
# Status: 200
#
# Request #106
# Status: 200
#
# Request #107
# Status: 200
#
# Request #108
# Status: 200
#
# Request #109
# Status: 200
#
# Request #110
# Status: 200
#
# Request #111
# Status: 200
#
# Request #112
# Status: 200
#
# Request #113
# Status: 200
#
# Request #114
# Status: 200
#
# Request #115
# Status: 200
#
# Request #116
# Status: 200
#
# Request #117
# Status: 200
#
# Request #118
# Status: 200
#
# Request #119
# Status: 200
#
# Request #120
# Status: 200
#
# Request #121
# Status: 200
#
# Request #122
# Status: 200
#
# Request #123
# Status: 200
#
# Request #124
# Status: 200
#
# Request #125
# Status: 200
#
# Request #126
# Status: 200
#
# Request #127
# Status: 200
#
# Request #128
# Status: 200
#
# Request #129
# Status: 200
#
# Request #130
# Status: 200
#
# Request #131
# Status: 200
#
# Request #132
# Status: 200
#
# Request #133
# Status: 200
#
# Request #134
# Status: 200
#
# Request #135
# Status: 200
#
# Request #136
# Status: 200
#
# Request #137
# Status: 200
#
# Request #138
# Status: 200
#
# Request #139
# Status: 200
#
# Request #140
# Status: 200
#
# Request #141
# Status: 200
#
# Request #142
# Status: 200
#
# Request #143
# Status: 200
#
# Request #144
# Status: 200
#
# Request #145
# Status: 200
#
# Request #146
# Status: 200
#
# Request #147
# Status: 200
#
# Request #148
# Status: 200
#
# Request #149
# Status: 200
#
# Request #150
# Status: 200
#
# Request #151
# Status: 200
#
# Request #152
# Status: 200
#
# Request #153
# Status: 200
#
# Request #154
# Status: 200
#
# Request #155
# Status: 200
#
# Request #156
# Status: 200
#
# Request #157
# Status: 200
#
# Request #158
# Status: 200
#
# Request #159
# Status: 200
#
# Request #160
# Status: 200
#
# Request #161
# Status: 200
#
# Request #162
# Status: 200
#
# Request #163
# Status: 200
#
# Request #164
# Status: 200
#
# Request #165
# Status: 200
#
# Request #166
# Status: 200
#
# Request #167
# Status: 200
#
# Request #168
# Status: 200
#
# Request #169
# Status: 200
#
# Request #170
# Status: 200
#
# Request #171
# Status: 200
#
# Request #172
# Status: 200
#
# Request #173
# Status: 200
#
# Request #174
# Status: 200
#
# Request #175
# Status: 200
#
# Request #176
# Status: 200
#
# Request #177
# Status: 200
#
# Request #178
# Status: 200
#
# Request #179
# Status: 200
#
# Request #180
# Status: 200
#
# Request #181
# Status: 200
#
# Request #182
# Status: 200
#
# Request #183
# Status: 200
#
# Request #184
# Status: 200
#
# Request #185
# Status: 200
#
# Request #186
# Status: 200
#
# Request #187
# Status: 200
#
# Request #188
# Status: 200
#
# Request #189
# Status: 200
#
# Request #190
# Status: 200
#
# Request #191
# Status: 200
#
# Request #192
# Status: 200
#
# Request #193
# Status: 200
#
# Request #194
# Status: 200
#
# Request #195
# Status: 200
#
# Request #196
# Status: 200
#
# Request #197
# Status: 200
#
# Request #198
# Status: 200
#
# Request #199
# Status: 200
#
# Request #200
# Status: 200
#
# Request #201
# Status: 200
#
# Request #202
# Status: 200
#
# Request #203
# Status: 200
#
# Request #204
# Status: 200
#
# Request #205
# Status: 200
#
# Request #206
# Status: 200
#
# Request #207
# Status: 200
#
# Request #208
# Status: 200
#
# Request #209
# Status: 200
#
# Request #210
# Status: 200
#
# Request #211
# Status: 200
#
# Request #212
# Status: 200
#
# Request #213
# Status: 200
#
# Request #214
# Status: 200
#
# Request #215
# Status: 200
#
# Request #216
# Status: 200
#
# Request #217
# Status: 200
#
# Request #218
# Status: 200
#
# Request #219
# Status: 200
#
# Request #220
# Status: 200
#
# Request #221
# Status: 200
#
# Request #222
# Status: 200
#
# Request #223
# Status: 200
#
# Request #224
# Status: 200
#
# Request #225
# Status: 200
#
# Request #226
# Status: 200
#
# Request #227
# Status: 200
#
# Request #228
# Status: 200
#
# Request #229
# Status: 200
#
# Request #230
# Status: 200
#
# Request #231
# Status: 200
#
# Request #232
# Status: 200
#
# Request #233
# Status: 200
#
# Request #234
# Status: 200
#
# Request #235
# Status: 200
#
# Request #236
# Status: 200
#
# Request #237
# Status: 200
#
# Request #238
# Status: 200
#
# Request #239
# Status: 200
#
# Request #240
# Status: 200
#
# Request #241
# Status: 200
#
# Request #242
# Status: 200
#
# Request #243
# Status: 200
#
# Request #244
# Status: 200
#
# Request #245
# Status: 200
#
# Request #246
# Status: 200
#
# Request #247
# Status: 200
#
# Request #248
# Status: 200
#
# Request #249
# Status: 200
#
# Request #250
# Status: 200
#
# Request #251
# Status: 200
#
# Request #252
# Status: 200
#
# Request #253
# Status: 200
#
# Request #254
# Status: 200
#
# Request #255
# Status: 200
#
# Request #256
# Status: 200
#
# Request #257
# Status: 200
#
# Request #258
# Status: 200
#
# Request #259
# Status: 200
#
# Request #260
# Status: 200
#
# Request #261
# Status: 200
#
# Request #262
# Status: 200
#
# Request #263
# Status: 200
#
# Request #264
# Status: 200
#
# Request #265
# Status: 200
#
# Request #266
# Status: 200
#
# Request #267
# Status: 200
#
# Request #268
# Status: 200
#
# Request #269
# Status: 200
#
# Request #270
# Status: 200
#
# Request #271
# Status: 200
#
# Request #272
# Status: 200
#
# Request #273
# Status: 200
#
# Request #274
# Status: 200
#
# Request #275
# Status: 200
#
# Request #276
# Status: 200
#
# Request #277
# Status: 200
#
# Request #278
# Status: 200
#
# Request #279
# Status: 200
#
# Request #280
# Status: 200
#
# Request #281
# Status: 200
#
# Request #282
# Status: 200
#
# Request #283
# Status: 200
#
# Request #284
# Status: 200
#
# Request #285
# Status: 200
#
# Request #286
# Status: 200
#
# Request #287
# Status: 200
#
# Request #288
# Status: 200
#
# Request #289
# Status: 200
#
# Request #290
# Status: 200
#
# Request #291
# Status: 200
#
# Request #292
# Status: 200
#
# Request #293
# Status: 200
#
# Request #294
# Status: 200
#
# Request #295
# Status: 200
#
# Request #296
# Status: 200
#
# Request #297
# Status: 200
#
# Request #298
# Status: 200
#
# Request #299
# Status: 200
#
# Request #300
# Status: 200
#
# Request #301
# Status: 200
#
# Request #302
# Status: 200
#
# Request #303
# Status: 200
#
# Request #304
# Status: 200
#
# Request #305
# Status: 200
#
# Request #306
# Status: 200
#
# Request #307
# Status: 200
#
# Request #308
# Status: 200
#
# Request #309
# Status: 200
#
# Request #310
# Status: 200
#
# Request #311
# Status: 200
#
# Request #312
# Status: 200
#
# Request #313
# Status: 200
#
# Request #314
# Status: 200
#
# Request #315
# Status: 200
#
# Request #316
# Status: 200
#
# Request #317
# Status: 200
#
# Request #318
# Status: 200
#
# Request #319
# Status: 200
#
# Request #320
# Status: 200
#
# Request #321
# Status: 200
#
# Request #322
# Status: 200
#
# Request #323
# Status: 200
#
# Request #324
# Status: 200
#
# Request #325
# Status: 200
#
# Request #326
# Status: 200
#
# Request #327
# Status: 200
#
# Request #328
# Status: 200
#
# Request #329
# Status: 200
#
# Request #330
# Status: 200
#
# Request #331
# Status: 200
#
# Request #332
# Status: 200
#
# Request #333
# Status: 200
#
# Request #334
# Status: 200
#
# Request #335
# Status: 200
#
# Request #336
# Status: 200
#
# Request #337
# Status: 200
#
# Request #338
# Status: 200
#
# Request #339
# Status: 200
#
# Request #340
# Status: 200
#
# Request #341
# Status: 200
#
# Request #342
# Status: 200
#
# Request #343
# Status: 200
#
# Request #344
# Status: 200
#
# Request #345
# Status: 200
#
# Request #346
# Status: 200
#
# Request #347
# Status: 200
#
# Request #348
# Status: 200
#
# Request #349
# Status: 200
#
# Request #350
# Status: 200
#
# Request #351
# Status: 200
#
# Request #352
# Status: 200
#
# Request #353
# Status: 200
#
# Request #354
# Status: 200
#
# Request #355
# Status: 200
#
# Request #356
# Status: 200
#
# Request #357
# Status: 200
#
# Request #358
# Status: 200
#
# Request #359
# Status: 200
#
# Request #360
# Status: 200
#
# Request #361
# Status: 200
#
# Request #362
# Status: 200
#
# Request #363
# Status: 200
#
# Request #364
# Status: 200
#
# Request #365
# Status: 200
#
# Request #366
# Status: 200
#
# Request #367
# Status: 200
#
# Request #368
# Status: 200
#
# Request #369
# Status: 200
#
# Request #370
# Status: 200
#
# Request #371
# Status: 200
#
# Request #372
# Status: 200
#
# Request #373
# Status: 200
#
# Request #374
# Status: 200
#
# Request #375
# Status: 200
#
# Request #376
# Status: 200
#
# Request #377
# Status: 200
#
# Request #378
# Status: 200
#
# Request #379
# Status: 200
#
# Request #380
# Status: 200
#
# Request #381
# Status: 200
#
# Request #382
# Status: 200
#
# Request #383
# Status: 200
#
# Request #384
# Status: 200
#
# Request #385
# Status: 200
#
# Request #386
# Status: 200
#
# Request #387
# Status: 200
#
# Request #388
# Status: 200
#
# Request #389
# Status: 200
#
# Request #390
# Status: 200
#
# Request #391
# Status: 200
#
# Request #392
# Status: 200
#
# Request #393
# Status: 200
#
# Request #394
# Status: 200
#
# Request #395
# Status: 200
#
# Request #396
# Status: 200
#
# Request #397
# Status: 200
#
# Request #398
# Status: 200
#
# Request #399
# Status: 200
#
# Request #400
# Status: 200
#
# Request #401
# Status: 200
#
# Request #402
# Status: 200
#
# Request #403
# Status: 200
#
# Request #404
# Status: 200
#
# Request #405
# Status: 200
#
# Request #406
# Status: 200
#
# Request #407
# Status: 200
#
# Request #408
# Status: 200
#
# Request #409
# Status: 200
#
# Request #410
# Status: 200
#
# Request #411
# Status: 200
#
# Request #412
# Status: 200
#
# Request #413
# Status: 200
#
# Request #414
# Status: 200
#
# Request #415
# Status: 200
#
# Request #416
# Status: 200
#
# Request #417
# Status: 200
#
# Request #418
# Status: 200
#
# Request #419
# Status: 200
#
# Request #420
# Status: 200
#
# Request #421
# Status: 200
#
# Request #422
# Status: 200
#
# Request #423
# Status: 200
#
# Request #424
# Status: 200
#
# Request #425
# Status: 200
#
# Request #426
# Status: 200
#
# Request #427
# Status: 200
#
# Request #428
# Status: 200
#
# Request #429
# Status: 200
#
# Request #430
# Status: 200
#
# Request #431
# Status: 200
#
# Request #432
# Status: 200
#
# Request #433
# Status: 200
#
# Request #434
# Status: 200
#
# Request #435
# Status: 200
#
# Request #436
# Status: 200
#
# Request #437
# Status: 200
#
# Request #438
# Status: 200
#
# Request #439
# Status: 200
#
# Request #440
# Status: 200
#
# Request #441
# Status: 200
#
# Request #442
# Status: 200
#
# Request #443
# Status: 200
#
# Request #444
# Status: 200
#
# Request #445
# Status: 200
#
# Request #446
# Status: 200
#
# Request #447
# Status: 200
#
# Request #448
# Status: 200
#
# Request #449
# Status: 200
#
# Request #450
# Status: 200
#
# Request #451
# Status: 200
#
# Request #452
# Status: 200
#
# Request #453
# Status: 200
#
# Request #454
# Status: 200
#
# Request #455
# Status: 200
#
# Request #456
# Status: 200
#
# Request #457
# Status: 200
#
# Request #458
# Status: 200
#
# Request #459
# Status: 200
#
# Request #460
# Status: 200
#
# Request #461
# Status: 200
#
# Request #462
# Status: 200
#
# Request #463
# Status: 200
#
# Request #464
# Status: 200
#
# Request #465
# Status: 200
#
# Request #466
# Status: 200
#
# Request #467
# Status: 200
#
# Request #468
# Status: 200
#
# Request #469
# Status: 200
#
# Request #470
# Status: 200
#
# Request #471
# Status: 200
#
# Request #472
# Status: 200
#
# Request #473
# Status: 200
#
# Request #474
# Status: 200
#
# Request #475
# Status: 200
#
# Request #476
# Status: 200
#
# Request #477
# Status: 200
#
# Request #478
# Status: 200
#
# Request #479
# Status: 200
#
# Request #480
# Status: 200
#
# Request #481
# Status: 200
#
# Request #482
# Status: 200
#
# Request #483
# Status: 200
#
# Request #484
# Status: 200
#
# Request #485
# Status: 200
#
# Request #486
# Status: 200
#
# Request #487
# Status: 200
#
# Request #488
# Status: 200
#
# Request #489
# Status: 200
#
# Request #490
# Status: 200
#
# Request #491
# Status: 200
#
# Request #492
# Status: 200
#
# Request #493
# Status: 200
#
# Request #494
# Status: 200
#
# Request #495
# Status: 200
#
# Request #496
# Status: 200
#
# Request #497
# Status: 200
#
# Request #498
# Status: 200
#
# Request #499
# Status: 200
#
# Request #500
# Status: 200
#
# Request #501
# Status: 200
#
# Request #502
# Status: 200
#
# Request #503
# Status: 200
#
# Request #504
# Status: 200
#
# Request #505
# Status: 200
#
# Request #506
# Status: 200
#
# Request #507
# Status: 200
#
# Request #508
# Status: 200
#
# Request #509
# Status: 200
#
# Request #510
# Status: 200
#
# Request #511
# Status: 200
#
# Request #512
# Status: 200
#
# Request #513
# Status: 200
#
# Request #514
# Status: 200
#
# Request #515
# Status: 200
#
# Request #516
# Status: 200
#
# Request #517
# Status: 200
#
# Request #518
# Status: 200
#
# Request #519
# Status: 200
#
# Request #520
# Status: 200
#
# Request #521
# Status: 200
#
# Request #522
# Status: 200
#
# Request #523
# Status: 200
#
# Request #524
# Status: 200
#
# Request #525
# Status: 200
#
# Request #526
# Status: 200
#
# Request #527
# Status: 200
#
# Request #528
# Status: 200
#
# Request #529
# Status: 200
#
# Request #530
# Status: 200
#
# Request #531
# Status: 200
#
# Request #532
# Status: 200
#
# Request #533
# Status: 200
#
# Request #534
# Status: 200
#
# Request #535
# Status: 200
#
# Request #536
# Status: 200
#
# Request #537
# Status: 200
#
# Request #538
# Status: 200
#
# Request #539
# Status: 200
#
# Request #540
# Status: 200
#
# Request #541
# Status: 200
#
# Request #542
# Status: 200
#
# Request #543
# Status: 200
#
# Request #544
# Status: 200
#
# Request #545
# Status: 200
#
# Request #546
# Status: 200
#
# Request #547
# Status: 200
#
# Request #548
# Status: 200
#
# Request #549
# Status: 200
#
# Request #550
# Status: 200
#
# Request #551
# Status: 200
#
# Request #552
# Status: 200
#
# Request #553
# Status: 200
#
# Request #554
# Status: 200
#
# Request #555
# Status: 200
#
# Request #556
# Status: 200
#
# Request #557
# Status: 200
#
# Request #558
# Status: 200
#
# Request #559
# Status: 200
#
# Request #560
# Status: 200
#
# Request #561
# Status: 200
#
# Request #562
# Status: 200
#
# Request #563
# Status: 200
#
# Request #564
# Status: 200
#
# Request #565
# Status: 200
#
# Request #566
# Status: 200
#
# Request #567
# Status: 200
#
# Request #568
# Status: 200
#
# Request #569
# Status: 200
#
# Request #570
# Status: 200
#
# Request #571
# Status: 200
#
# Request #572
# Status: 200
#
# Request #573
# Status: 200
#
# Request #574
# Status: 200
#
# Request #575
# Status: 200
#
# Request #576
# Status: 200
#
# Request #577
# Status: 200
#
# Request #578
# Status: 200
#
# Request #579
# Status: 200
#
# Request #580
# Status: 200
#
# Request #581
# Status: 200
#
# Request #582
# Status: 200
#
# Request #583
# Status: 200
#
# Request #584
# Status: 200
#
# Request #585
# Status: 200
#
# Request #586
# Status: 200
#
# Request #587
# Status: 200
#
# Request #588
# Status: 200
#
# Request #589
# Status: 200
#
# Request #590
# Status: 200
#
# Request #591
# Status: 200
#
# Request #592
# Status: 200
#
# Request #593
# Status: 200
#
# Request #594
# Status: 200
#
# Request #595
# Status: 200
#
# Request #596
# Status: 200
#
# Request #597
# Status: 200
#
# Request #598
# Status: 200
#
# Request #599
# Status: 200
#
# Request #600
# Status: 200
#
# Request #601
# Status: 200
#
# Request #602
# Status: 200
#
# Request #603
# Status: 200
#
# Request #604
# Status: 200
#
# Request #605
# Status: 200
#
# Request #606
# Status: 200
#
# Request #607
# Status: 200
#
# Request #608
# Status: 200
#
# Request #609
# Status: 200
#
# Request #610
# Status: 200
#
# Request #611
# Status: 200
#
# Request #612
# Status: 200
#
# Request #613
# Status: 200
#
# Request #614
# Status: 200
#
# Request #615
# Status: 200
#
# Request #616
# Status: 200
#
# Request #617
# Status: 200
#
# Request #618
# Status: 200
#
# Request #619
# Status: 200
#
# Request #620
# Status: 200
#
# Request #621
# Status: 200
#
# Request #622
# Status: 200
#
# Request #623
# Status: 200
#
# Request #624
# Status: 200
#
# Request #625
# Status: 200
#
# Request #626
# Status: 200
#
# Request #627
# Status: 200
#
# Request #628
# Status: 200
#
# Request #629
# Status: 200
#
# Request #630
# Status: 200
#
# Request #631
# Status: 200
#
# Request #632
# Status: 200
#
# Request #633
# Status: 200
#
# Request #634
# Status: 200
#
# Request #635
# Status: 200
#
# Request #636
# Status: 200
#
# Request #637
# Status: 200
#
# Request #638
# Status: 200
#
# Request #639
# Status: 200
#
# Request #640
# Status: 200
#
# Request #641
# Status: 200
#
# Request #642
# Status: 200
#
# Request #643
# Status: 200
#
# Request #644
# Status: 200
#
# Request #645
# Status: 200
#
# Request #646
# Status: 200
#
# Request #647
# Status: 200
#
# Request #648
# Status: 200
#
# Request #649
# Status: 200
#
# Request #650
# Status: 200
#
# Request #651
# Status: 200
#
# Request #652
# Status: 200
#
# Request #653
# Status: 200
#
# Request #654
# Status: 200
#
# Request #655
# Status: 200
#
# Request #656
# Status: 200
#
# Request #657
# Status: 200
#
# Request #658
# Status: 200
#
# Request #659
# Status: 200
#
# Request #660
# Status: 200
#
# Request #661
# Status: 200
#
# Request #662
# Status: 200
#
# Request #663
# Status: 200
#
# Request #664
# Status: 200
#
# Request #665
# Status: 200
#
# Request #666
# Status: 200
#
# Request #667
# Status: 200
#
# Request #668
# Status: 200
#
# Request #669
# Status: 200
#
# Request #670
# Status: 200
#
# Request #671
# Status: 200
#
# Request #672
# Status: 200
#
# Request #673
# Status: 200
#
# Request #674
# Status: 200
#
# Request #675
# Status: 200
#
# Request #676
# Status: 200
#
# Request #677
# Status: 200
#
# Request #678
# Status: 200
#
# Request #679
# Status: 200
#
# Request #680
# Status: 200
#
# Request #681
# Status: 200
#
# Request #682
# Status: 200
#
# Request #683
# Status: 200
#
# Request #684
# Status: 200
#
# Request #685
# Status: 200
#
# Request #686
# Status: 200
#
# Request #687
# Status: 200
#
# Request #688
# Status: 200
#
# Request #689
# Status: 200
#
# Request #690
# Status: 200
#
# Request #691
# Status: 200
#
# Request #692
# Status: 200
#
# Request #693
# Status: 200
#
# Request #694
# Status: 200
#
# Request #695
# Status: 200
#
# Request #696
# Status: 200
#
# Request #697
# Status: 200
#
# Request #698
# Status: 200
#
# Request #699
# Status: 200
#
# Request #700
# Status: 200
#
# Finished. Collected 11200 posts for entity 7836
# Results saved to filtered_posts_20250712_235934.json
#
# Verification:
# First post entity_id: 7836
# Last post entity_id: 7836
# Unique entity_ids found: 1

# %%
import requests
import time
import json
from datetime import datetime
import os

# Configuration
API_URL = "https://rahavard365.com/api/v2/social/posts"
OUTPUT_FILE = f"filtered_posts_{datetime.now().strftime('%Y%m%d_%H%M%S')}.json"
TARGET_ENTITY_ID = "7836"  # specific entity ID
MAX_REQUESTS = 100
DELAY = 1.5  # seconds

# Headers from browser inspection
headers = {
    "authority": "rahavard365.com",
    "accept": "application/json, text/plain, */*",
    "accept-language": "en-US,en;q=0.9",
    "application-name": "rahavard",
    "content-type": "application/json",
    "referer": "https://rahavard365.com/social",
    "user-agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/123.0.0.0 Safari/537.36"
}

# Initialize storage
filtered_posts = []
last_id = None
request_count = 0

# Try to find the most recent output file to resume from
def find_latest_output_file():
    files = [f for f in os.listdir() if f.startswith("filtered_posts_") and f.endswith(".json")]
    if not files:
        return None
    return max(files, key=lambda x: os.path.getmtime(x))

# Load existing data if available
latest_file = find_latest_output_file()
if latest_file:
    try:
        with open(latest_file, "r", encoding="utf-8") as f:
            existing_data = json.load(f)
            if existing_data:
                filtered_posts = existing_data.copy()
                last_id = existing_data[-1]["id"]
                print(f"Resuming from existing data. Loaded {len(existing_data)} posts. Last ID: {last_id}")
    except Exception as e:
        print(f"Error loading existing file: {str(e)}")
        print("Starting fresh collection")

print(f"Starting to collect posts for entity ID: {TARGET_ENTITY_ID}")

while request_count < MAX_REQUESTS:
    # Prepare parameters
    params = {
        "exclude_replies": "true",
        "has_chart_analysis": "false",
        "_count": 16,
        "entity_id": TARGET_ENTITY_ID,
        "entity_type": "exchange.asset",
        "_t": int(time.time() * 1000),
    }
    
    if last_id:
        params["before_id"] = last_id
    
    try:
        print(f"\nRequest #{request_count + 1}")
        # print(f"Params: {params}")
        
        response = requests.get(
            API_URL,
            params=params,
            headers=headers,
            timeout=10
        )
        request_count += 1
        
        print(f"Status: {response.status_code}")
        
        if response.status_code == 200:
            data = response.json()
            
            if isinstance(data, dict) and data.get("data"):
                batch = data["data"]
                
                if not batch:
                    print("No more posts available")
                    break
                
                # Verify entity_id in each post
                valid_posts = [
                    p for p in batch 
                    if str(p.get("entity_id")) == TARGET_ENTITY_ID
                ]
                
                if len(valid_posts) != len(batch):
                    print(f"Filtered {len(batch) - len(valid_posts)} posts with wrong entity_id")
                
                if valid_posts:
                    filtered_posts.extend(valid_posts)
                    last_id = valid_posts[-1]["id"]
                    print(f"Added {len(valid_posts)} valid posts (Total: {len(filtered_posts)})")
                else:
                    print("No valid posts in this batch")
                    break
            else:
                print("Unexpected response format")
                break
        else:
            print(f"HTTP Error {response.status_code}")
            break
            
        time.sleep(DELAY)
        
    except Exception as e:
        print(f"Error: {str(e)}")
        # Save what we have so far in case of error
        with open(OUTPUT_FILE, "w", encoding="utf-8") as f:
            json.dump(filtered_posts, f, ensure_ascii=False, indent=2)
        print(f"Saved intermediate results to {OUTPUT_FILE}")
        break

# Save results
print(f"\nFinished. Collected {len(filtered_posts)} posts for entity {TARGET_ENTITY_ID}")
with open(OUTPUT_FILE, "w", encoding="utf-8") as f:
    json.dump(filtered_posts, f, ensure_ascii=False, indent=2)

print(f"Results saved to {OUTPUT_FILE}")

# Verification
if filtered_posts:
    print("\nVerification:")
    print(f"First post entity_id: {filtered_posts[0].get('entity_id')}")
    print(f"Last post entity_id: {filtered_posts[-1].get('entity_id')}")
    print(f"Unique entity_ids found: {len(set(p.get('entity_id') for p in filtered_posts))}")
# Out:
# Resuming from existing data. Loaded 11200 posts. Last ID: 12617935
# Starting to collect posts for entity ID: 7836
#
# Request #1
# Status: 200
# Added 16 valid posts (Total: 11216)
#
# Request #2
# Status: 200
# Added 16 valid posts (Total: 11232)
#
# Request #3
# Status: 200
# Added 16 valid posts (Total: 11248)
#
# Request #4
# Status: 200
# Added 16 valid posts (Total: 11264)
#
# Request #5
# Status: 200
# Added 16 valid posts (Total: 11280)
#
# Request #6
# Status: 200
# Added 16 valid posts (Total: 11296)
#
# Request #7
# Status: 200
# Added 16 valid posts (Total: 11312)
#
# Request #8
# Status: 200
# Added 16 valid posts (Total: 11328)
#
# Request #9
# Status: 200
# Added 16 valid posts (Total: 11344)
#
# Request #10
# Status: 200
# Added 16 valid posts (Total: 11360)
#
# Request #11
# Status: 200
# Added 16 valid posts (Total: 11376)
#
# Request #12
# Status: 200
# Added 16 valid posts (Total: 11392)
#
# Request #13
# Status: 200
# Added 16 valid posts (Total: 11408)
#
# Request #14
# Status: 200
# Added 16 valid posts (Total: 11424)
#
# Request #15
# Status: 200
# Added 16 valid posts (Total: 11440)
#
# Request #16
# Status: 200
# Added 16 valid posts (Total: 11456)
#
# Request #17
# Status: 200
# Added 16 valid posts (Total: 11472)
#
# Request #18
# Status: 200
# Added 16 valid posts (Total: 11488)
#
# Request #19
# Status: 200
# Added 16 valid posts (Total: 11504)
#
# Request #20
# Status: 200
# Added 16 valid posts (Total: 11520)
#
# Request #21
# Status: 200
# Added 16 valid posts (Total: 11536)
#
# Request #22
# Status: 200
# Added 16 valid posts (Total: 11552)
#
# Request #23
# Status: 200
# Added 16 valid posts (Total: 11568)
#
# Request #24
# Status: 200
# Added 16 valid posts (Total: 11584)
#
# Request #25
# Status: 200
# Added 16 valid posts (Total: 11600)
#
# Request #26
# Status: 200
# Added 16 valid posts (Total: 11616)
#
# Request #27
# Status: 200
# Added 16 valid posts (Total: 11632)
#
# Request #28
# Status: 200
# Added 16 valid posts (Total: 11648)
#
# Request #29
# Status: 200
# Added 16 valid posts (Total: 11664)
#
# Request #30
# Status: 200
# Added 16 valid posts (Total: 11680)
#
# Request #31
# Status: 200
# Added 16 valid posts (Total: 11696)
#
# Request #32
# Status: 200
# Added 16 valid posts (Total: 11712)
#
# Request #33
# Status: 200
# Added 16 valid posts (Total: 11728)
#
# Request #34
# Status: 200
# Added 16 valid posts (Total: 11744)
#
# Request #35
# Status: 200
# Added 16 valid posts (Total: 11760)
#
# Request #36
# Status: 200
# Added 16 valid posts (Total: 11776)
#
# Request #37
# Status: 200
# Added 16 valid posts (Total: 11792)
#
# Request #38
# Status: 200
# Added 16 valid posts (Total: 11808)
#
# Request #39
# Status: 200
# Added 16 valid posts (Total: 11824)
#
# Request #40
# Status: 200
# Added 16 valid posts (Total: 11840)
#
# Request #41
# Status: 200
# Added 16 valid posts (Total: 11856)
#
# Request #42
# Status: 200
# Added 16 valid posts (Total: 11872)
#
# Request #43
# Status: 200
# Added 16 valid posts (Total: 11888)
#
# Request #44
# Status: 200
# Added 16 valid posts (Total: 11904)
#
# Request #45
# Status: 200
# Added 16 valid posts (Total: 11920)
#
# Request #46
# Status: 200
# Added 16 valid posts (Total: 11936)
#
# Request #47
# Status: 200
# Added 16 valid posts (Total: 11952)
#
# Request #48
# Status: 200
# Added 16 valid posts (Total: 11968)
#
# Request #49
# Status: 200
# Added 16 valid posts (Total: 11984)
#
# Request #50
# Status: 200
# Added 16 valid posts (Total: 12000)
#
# Request #51
# Status: 200
# Added 16 valid posts (Total: 12016)
#
# Request #52
# Status: 200
# Added 16 valid posts (Total: 12032)
#
# Request #53
# Status: 200
# Added 16 valid posts (Total: 12048)
#
# Request #54
# Status: 200
# Added 16 valid posts (Total: 12064)
#
# Request #55
# Status: 200
# Added 16 valid posts (Total: 12080)
#
# Request #56
# Status: 200
# Added 16 valid posts (Total: 12096)
#
# Request #57
# Status: 200
# Added 16 valid posts (Total: 12112)
#
# Request #58
# Status: 200
# Added 16 valid posts (Total: 12128)
#
# Request #59
# Status: 200
# Added 16 valid posts (Total: 12144)
#
# Request #60
# Status: 200
# Added 16 valid posts (Total: 12160)
#
# Request #61
# Status: 200
# Added 16 valid posts (Total: 12176)
#
# Request #62
# Status: 200
# Added 16 valid posts (Total: 12192)
#
# Request #63
# Status: 200
# Added 16 valid posts (Total: 12208)
#
# Request #64
# Status: 200
# Added 16 valid posts (Total: 12224)
#
# Request #65
# Status: 200
# Added 16 valid posts (Total: 12240)
#
# Request #66
# Status: 200
# Added 16 valid posts (Total: 12256)
#
# Request #67
# Status: 200
# Added 16 valid posts (Total: 12272)
#
# Request #68
# Status: 200
# Added 16 valid posts (Total: 12288)
#
# Request #69
# Status: 200
# Added 16 valid posts (Total: 12304)
#
# Request #70
# Status: 200
# Added 16 valid posts (Total: 12320)
#
# Request #71
# Status: 200
# Added 16 valid posts (Total: 12336)
#
# Request #72
# Status: 200
# Added 16 valid posts (Total: 12352)
#
# Request #73
# Status: 200
# Added 16 valid posts (Total: 12368)
#
# Request #74
# Status: 200
# Added 16 valid posts (Total: 12384)
#
# Request #75
# Status: 200
# Added 16 valid posts (Total: 12400)
#
# Request #76
# Status: 200
# Added 16 valid posts (Total: 12416)
#
# Request #77
# Status: 200
# Added 16 valid posts (Total: 12432)
#
# Request #78
# Status: 200
# Added 16 valid posts (Total: 12448)
#
# Request #79
# Status: 200
# Added 16 valid posts (Total: 12464)
#
# Request #80
# Status: 200
# Added 16 valid posts (Total: 12480)
#
# Request #81
# Status: 200
# Added 16 valid posts (Total: 12496)
#
# Request #82
# Status: 200
# Added 16 valid posts (Total: 12512)
#
# Request #83
# Status: 200
# Added 16 valid posts (Total: 12528)
#
# Request #84
# Status: 200
# Added 16 valid posts (Total: 12544)
#
# Request #85
# Status: 200
# Added 16 valid posts (Total: 12560)
#
# Request #86
# Status: 200
# Added 16 valid posts (Total: 12576)
#
# Request #87
# Status: 200
# Added 16 valid posts (Total: 12592)
#
# Request #88
# Status: 200
# Added 16 valid posts (Total: 12608)
#
# Request #89
# Status: 200
# Added 16 valid posts (Total: 12624)
#
# Request #90
# Status: 200
# Added 16 valid posts (Total: 12640)
#
# Request #91
# Status: 200
# Added 16 valid posts (Total: 12656)
#
# Request #92
# Status: 200
# Added 16 valid posts (Total: 12672)
#
# Request #93
# Status: 200
# Added 16 valid posts (Total: 12688)
#
# Request #94
# Status: 200
# Added 16 valid posts (Total: 12704)
#
# Request #95
# Status: 200
# Added 16 valid posts (Total: 12720)
#
# Request #96
# Status: 200
# Added 16 valid posts (Total: 12736)
#
# Request #97
# Status: 200
# Added 16 valid posts (Total: 12752)
#
# Request #98
# Status: 200
# Added 16 valid posts (Total: 12768)
#
# Request #99
# Status: 200
# Added 16 valid posts (Total: 12784)
#
# Request #100
# Status: 200
# Added 16 valid posts (Total: 12800)
#
# Finished. Collected 12800 posts for entity 7836
# Results saved to filtered_posts_20250713_003423.json
#
# Verification:
# First post entity_id: 7836
# Last post entity_id: 7836
# Unique entity_ids found: 1
